# %% [markdown]
# ### Final edit

# %%
import time
import pyautogui
import keyboard
from tkinter import Tk, messagebox

player_positions = [
    (970, 540),  # player1
    (970, 630),  # player2
    (970, 720),  # player3
    (970, 810),  # player4
    (970, 900),  # player5
    (970, 990),  # player6
    (970, 1080)  # player7
]

x = 970
y = 540
i = 0
k = 113

# Start timer
start_time = time.time()
print("Automation started...")

while i<3369:  # 43797 is the whole data i will need to make it into 13 patch to have more thatn one safe fale point so 43797 divided by 13 is 3369
    # Allow manual quit
    if keyboard.is_pressed('tab'):
        elapsed = time.time() - start_time
        print(f"Automation stopped by user at iteration {i} of 3369")
        print(f"Shortlist counter (k): {k}")
        print(f"Time elapsed: {elapsed/60:.2f} minutes ({elapsed:.2f} seconds)")
        break

    # --- Use Ctrl+click for normal selections ---
    with pyautogui.hold('ctrl'):
        pyautogui.click(x, y)

    # --- Special actions after every 200 players ---
    if i != 0 and (i + 1) % 200 == 0:
        if (x, y) == player_positions[0]:                 #player 1
            time.sleep(2)
            pyautogui.click(1335, 1145)                   # shortlist button
            time.sleep(2)
            pyautogui.doubleClick(935, 603)               # the write Bar to write the shortlsit name
            time.sleep(2)
            pyautogui.write(f"shortlist {k}")             # name the shortlist  
            time.sleep(2)
            pyautogui.press("enter")                      # press enter
            time.sleep(2)
            pyautogui.click(1165,120)                     # click the top shortlist button 
            time.sleep(2)
            pyautogui.hotkey("ctrl", "p")                 # print the shortlist
            time.sleep(2)
            pyautogui.click(1080,706)                     # click ok button to print the shortlist
            time.sleep(2)
            pyautogui.doubleClick(630,555)                # click the data folder    
            time.sleep(2)
            pyautogui.doubleClick(630,555)                # save in the first folder
            time.sleep(2)
            pyautogui.doubleClick(939,328)                # double click to name the data
            time.sleep(2)
            pyautogui.write(f"shortlist {k}")             # change the name 
            time.sleep(2)
            pyautogui.press("enter")                      # press enter
            time.sleep(2)
            pyautogui.click(615,122)                      # retuen to player range
            time.sleep(2)
            pyautogui.doubleClick(player_positions[1])    
            time.sleep(2)
            y += 90
            i += 1
            k += 1
           

        elif (x, y) == player_positions[1]:              #player 2
            time.sleep(2)
            pyautogui.click(1335, 1145)                   # shortlist button
            time.sleep(2)
            pyautogui.doubleClick(935, 603)               # the write Bar to write the shortlsit name
            time.sleep(2)
            pyautogui.write(f"shortlist {k}")             # name the shortlist  
            time.sleep(2)
            pyautogui.press("enter")                      # press enter
            time.sleep(2)
            pyautogui.click(1165,120)                     # click the top shortlist button 
            time.sleep(2)
            pyautogui.hotkey("ctrl", "p")                 # print the shortlist
            time.sleep(2)
            pyautogui.click(1080,706)                     # click ok button to print the shortlist
            time.sleep(2)
            pyautogui.doubleClick(630,555)                # click the data folder    
            time.sleep(2)
            pyautogui.doubleClick(630,555)                # save in the first folder
            time.sleep(2)
            pyautogui.doubleClick(939,328)                # double click to name the data
            time.sleep(2)
            pyautogui.write(f"shortlist {k}")             # change the name 
            time.sleep(2)
            pyautogui.press("enter")                      # press enter
            time.sleep(2)
            pyautogui.click(615,122)                      # retuen to player range
            time.sleep(2)
            pyautogui.doubleClick(player_positions[2])
            time.sleep(2)
            y += 90
            i += 1
            k += 1
            

        elif (x, y) == player_positions[2]:              #player 3
            time.sleep(2)
            pyautogui.click(1335, 1145)                   # shortlist button
            time.sleep(2)
            pyautogui.doubleClick(935, 603)               # the write Bar to write the shortlsit name
            time.sleep(2)
            pyautogui.write(f"shortlist {k}")             # name the shortlist  
            time.sleep(2)
            pyautogui.press("enter")                      # press enter
            time.sleep(2)
            pyautogui.click(1165,120)                     # click the top shortlist button 
            time.sleep(2)
            pyautogui.hotkey("ctrl", "p")                 # print the shortlist
            time.sleep(2)
            pyautogui.click(1080,706)                     # click ok button to print the shortlist
            time.sleep(2)
            pyautogui.doubleClick(630,555)                # click the data folder    
            time.sleep(2)
            pyautogui.doubleClick(630,555)                # save in the first folder
            time.sleep(2)
            pyautogui.doubleClick(939,328)                # double click to name the data
            time.sleep(2)
            pyautogui.write(f"shortlist {k}")             # change the name 
            time.sleep(2)
            pyautogui.press("enter")                      # press enter
            time.sleep(2)
            pyautogui.click(615,122)                      # retuen to player range
            time.sleep(2)
            pyautogui.doubleClick(player_positions[3])
            time.sleep(2)
            y += 90
            i += 1
            k += 1
            

        elif (x, y) == player_positions[3]:              #player 4
            time.sleep(2)
            pyautogui.click(1335, 1145)                   # shortlist button
            time.sleep(2)
            pyautogui.doubleClick(935, 603)               # the write Bar to write the shortlsit name
            time.sleep(2)
            pyautogui.write(f"shortlist {k}")             # name the shortlist  
            time.sleep(2)
            pyautogui.press("enter")                      # press enter
            time.sleep(2)
            pyautogui.click(1165,120)                     # click the top shortlist button 
            time.sleep(2)
            pyautogui.hotkey("ctrl", "p")                 # print the shortlist
            time.sleep(2)
            pyautogui.click(1080,706)                     # click ok button to print the shortlist
            time.sleep(2)
            pyautogui.doubleClick(630,555)                # click the data folder    
            time.sleep(2)
            pyautogui.doubleClick(630,555)                # save in the first folder
            time.sleep(2)
            pyautogui.doubleClick(939,328)                # double click to name the data
            time.sleep(2)
            pyautogui.write(f"shortlist {k}")             # change the name 
            time.sleep(2)
            pyautogui.press("enter")                      # press enter
            time.sleep(2)
            pyautogui.click(615,122)                      # retuen to player range
            time.sleep(2)
            pyautogui.doubleClick(player_positions[4])
            time.sleep(2)
            y += 90
            i += 1
            k += 1
            

        elif (x, y) == player_positions[4]:              #player 5
            time.sleep(2)
            pyautogui.click(1335, 1145)                   # shortlist button
            time.sleep(2)
            pyautogui.doubleClick(935, 603)               # the write Bar to write the shortlsit name
            time.sleep(2)
            pyautogui.write(f"shortlist {k}")             # name the shortlist  
            time.sleep(2)
            pyautogui.press("enter")                      # press enter
            time.sleep(2)
            pyautogui.click(1165,120)                     # click the top shortlist button 
            time.sleep(2)
            pyautogui.hotkey("ctrl", "p")                 # print the shortlist
            time.sleep(2)
            pyautogui.click(1080,706)                     # click ok button to print the shortlist
            time.sleep(2)
            pyautogui.doubleClick(630,555)                # click the data folder    
            time.sleep(2)
            pyautogui.doubleClick(630,555)                # save in the first folder
            time.sleep(2)
            pyautogui.doubleClick(939,328)                # double click to name the data
            time.sleep(2)
            pyautogui.write(f"shortlist {k}")             # change the name 
            time.sleep(2)
            pyautogui.press("enter")                      # press enter
            time.sleep(2)
            pyautogui.click(615,122)                      # retuen to player range
            time.sleep(2)
            pyautogui.doubleClick(player_positions[5])
            time.sleep(2)
            y += 90
            i += 1
            k += 1
           

        elif (x, y) == player_positions[5]:              #player 6
            time.sleep(2)
            pyautogui.click(1335, 1145)                   # shortlist button
            time.sleep(2)
            pyautogui.doubleClick(935, 603)               # the write Bar to write the shortlsit name
            time.sleep(2)
            pyautogui.write(f"shortlist {k}")             # name the shortlist  
            time.sleep(2)
            pyautogui.press("enter")                      # press enter
            time.sleep(2)
            pyautogui.click(1165,120)                     # click the top shortlist button 
            time.sleep(2)
            pyautogui.hotkey("ctrl", "p")                 # print the shortlist
            time.sleep(2)
            pyautogui.click(1080,706)                     # click ok button to print the shortlist
            time.sleep(2)
            pyautogui.doubleClick(630,555)                # click the data folder    
            time.sleep(2)
            pyautogui.doubleClick(630,555)                # save in the first folder
            time.sleep(2)
            pyautogui.doubleClick(939,328)                # double click to name the data
            time.sleep(2)
            pyautogui.write(f"shortlist {k}")             # change the name 
            time.sleep(2)
            pyautogui.press("enter")                      # press enter
            time.sleep(2)
            pyautogui.click(615,122)                      # retuen to player range
            time.sleep(2)
            pyautogui.doubleClick(player_positions[6])
            time.sleep(2)
            y += 90
            i += 1
            k += 1
            

        elif (x, y) == player_positions[6]:              #player 7
            time.sleep(2)
            pyautogui.click(1335, 1145)                   # shortlist button
            time.sleep(2)
            pyautogui.doubleClick(935, 603)               # the write Bar to write the shortlsit name
            time.sleep(2)
            pyautogui.write(f"shortlist {k}")             # name the shortlist  
            time.sleep(2)
            pyautogui.press("enter")                      # press enter
            time.sleep(2)
            pyautogui.click(1165,120)                     # click the top shortlist button 
            time.sleep(2)
            pyautogui.hotkey("ctrl", "p")                 # print the shortlist
            time.sleep(2)
            pyautogui.click(1080,706)                     # click ok button to print the shortlist
            time.sleep(2)
            pyautogui.doubleClick(630,555)                # click the data folder    
            time.sleep(2)
            pyautogui.doubleClick(630,555)                # save in the first folder
            time.sleep(2)
            pyautogui.doubleClick(939,328)                # double click to name the data
            time.sleep(2)
            pyautogui.write(f"shortlist {k}")             # change the name 
            time.sleep(2)
            pyautogui.press("enter")                      # press enter
            time.sleep(2)
            pyautogui.click(615,122)                      # retuen to player range
            time.sleep(2)
            y += 90
            i += 1
            k += 1
            pyautogui.click(player_positions[6])
            pyautogui.scroll(-840)
            pyautogui.doubleClick(player_positions[0])
            time.sleep(2)
            y = 540

            
    # Increment position for normal loop
    y += 90
    i += 1
    

    if i % 7 == 0:
        pyautogui.scroll(-840)
        y = 540

# If completed normally (didn't break from Tab key)
else:
    elapsed = time.time() - start_time
    print(f"Automation completed successfully in {elapsed/60:.2f} minutes ({elapsed:.2f} seconds)")
    print(f"Total shortlists created: {k}")
    print(f"Final iteration count: {i}")
    
    # Show popup with completion info
    root = Tk()
    root.withdraw()  # Hide the main window
    messagebox.showinfo(
        "Automation Complete",
        f"Automation completed successfully!\n\n"
        f"Time elapsed: {elapsed/60:.2f} minutes ({elapsed:.2f} seconds)\n"
        f"Total shortlists created: {k}\n"
        f"Final iteration count: {i}"
    )
    root.destroy()

# %%
import time
import pyautogui
import keyboard
from tkinter import Tk, messagebox

player_positions = [
    (970, 540),  # player1
    (970, 630),  # player2
    (970, 720),  # player3
    (970, 810),  # player4
    (970, 900),  # player5
    (970, 990),  # player6
    (970, 1080)  # player7
]

x = 970
y = 540
i = 0
k = 225

# Start timer
start_time = time.time()
print("Automation started...")

while i<200:  # 43797 is the whole data i will need to make it into 13 patch to have more thatn one safe fale point so 43797 divided by 13 is 3369
    # Allow manual quit
    if keyboard.is_pressed('tab'):
        elapsed = time.time() - start_time
        print(f"Automation stopped by user at iteration {i} of 3369")
        print(f"Shortlist counter (k): {k}")
        print(f"Time elapsed: {elapsed/60:.2f} minutes ({elapsed:.2f} seconds)")
        break

    # --- Use Ctrl+click for normal selections ---
    with pyautogui.hold('ctrl'):
        pyautogui.click(x, y)

    # --- Special actions after every 200 players ---
    if i != 0 and (i + 1) % 200 == 0:
        if (x, y) == player_positions[0]:                 #player 1
            time.sleep(2)
            pyautogui.click(1335, 1145)                   # shortlist button
            time.sleep(2)
            pyautogui.doubleClick(935, 603)               # the write Bar to write the shortlsit name
            time.sleep(2)
            pyautogui.write(f"shortlist {k}")             # name the shortlist  
            time.sleep(2)
            pyautogui.press("enter")                      # press enter
            time.sleep(6)
            pyautogui.doubleClick(player_positions[1])    
            time.sleep(2)
            y += 90
            i += 1
            k += 1
           

        elif (x, y) == player_positions[1]:              #player 2
            time.sleep(2)
            pyautogui.click(1335, 1145)                   # shortlist button
            time.sleep(2)
            pyautogui.doubleClick(935, 603)               # the write Bar to write the shortlsit name
            time.sleep(2)
            pyautogui.write(f"shortlist {k}")             # name the shortlist  
            time.sleep(2)
            pyautogui.press("enter")                      # press enter
            time.sleep(6)
            pyautogui.doubleClick(player_positions[2])
            time.sleep(2)
            y += 90
            i += 1
            k += 1
            

        elif (x, y) == player_positions[2]:              #player 3
            time.sleep(2)
            pyautogui.click(1335, 1145)                   # shortlist button
            time.sleep(2)
            pyautogui.doubleClick(935, 603)               # the write Bar to write the shortlsit name
            time.sleep(2)
            pyautogui.write(f"shortlist {k}")             # name the shortlist  
            time.sleep(2)
            pyautogui.press("enter")                      # press enter
            time.sleep(6)
            pyautogui.doubleClick(player_positions[3])
            time.sleep(2)
            y += 90
            i += 1
            k += 1
            

        elif (x, y) == player_positions[3]:              #player 4
            time.sleep(2)
            pyautogui.click(1335, 1145)                   # shortlist button
            time.sleep(2)
            pyautogui.doubleClick(935, 603)               # the write Bar to write the shortlsit name
            time.sleep(2)
            pyautogui.write(f"shortlist {k}")             # name the shortlist  
            time.sleep(2)
            pyautogui.press("enter")                      # press enter
            time.sleep(6)
            pyautogui.doubleClick(player_positions[4])
            time.sleep(2)
            y += 90
            i += 1
            k += 1
            

        elif (x, y) == player_positions[4]:              #player 5
            time.sleep(2)
            pyautogui.click(1335, 1145)                   # shortlist button
            time.sleep(2)
            pyautogui.doubleClick(935, 603)               # the write Bar to write the shortlsit name
            time.sleep(2)
            pyautogui.write(f"shortlist {k}")             # name the shortlist  
            time.sleep(2)
            pyautogui.press("enter")                      # press enter
            time.sleep(6)
            pyautogui.doubleClick(player_positions[5])
            time.sleep(2)
            y += 90
            i += 1
            k += 1
           

        elif (x, y) == player_positions[5]:              #player 6
            time.sleep(2)
            pyautogui.click(1335, 1145)                   # shortlist button
            time.sleep(2)
            pyautogui.doubleClick(935, 603)               # the write Bar to write the shortlsit name
            time.sleep(2)
            pyautogui.write(f"shortlist {k}")             # name the shortlist  
            time.sleep(2)
            pyautogui.press("enter")                      # press enter
            time.sleep(6)
            pyautogui.doubleClick(player_positions[6])
            time.sleep(2)
            y += 90
            i += 1
            k += 1
            

        elif (x, y) == player_positions[6]:              #player 7
            time.sleep(2)
            pyautogui.click(1335, 1145)                   # shortlist button
            time.sleep(2)
            pyautogui.doubleClick(935, 603)               # the write Bar to write the shortlsit name
            time.sleep(2)
            pyautogui.write(f"shortlist {k}")             # name the shortlist  
            time.sleep(2)
            pyautogui.press("enter")                      # press enter
            time.sleep(6)
            y += 90
            i += 1
            k += 1
            pyautogui.click(player_positions[6])
            time.sleep(2)
            pyautogui.scroll(-840)
            time.sleep(2)
            pyautogui.doubleClick(player_positions[0])
            time.sleep(2)
            y = 540

            
    # Increment position for normal loop
    y += 90
    i += 1
    

    if i % 7 == 0:
        pyautogui.scroll(-840)
        y = 540

# If completed normally (didn't break from Tab key)
else:
    elapsed = time.time() - start_time
    print(f"Automation completed successfully in {elapsed/60:.2f} minutes ({elapsed:.2f} seconds)")
    print(f"Total shortlists created: {k}")
    print(f"Final iteration count: {i}")
    
    # Show popup with completion info
    root = Tk()
    root.withdraw()  # Hide the main window
    messagebox.showinfo(
        "Automation Complete",
        f"Automation completed successfully!\n\n"
        f"Time elapsed: {elapsed/60:.2f} minutes ({elapsed:.2f} seconds)\n"
        f"Total shortlists created: {k}\n"
        f"Final iteration count: {i}"
    )
    root.destroy()
# Out:
# Automation started...
# Automation completed successfully in 1.01 minutes (60.75 seconds)
# Total shortlists created: 226
# Final iteration count: 201
